# %% [markdown]
# ### Méthode de Newton

# %% [markdown]
# ```Methode Newton: approximation de la solutions d'une équation avec une précision meilleur que la méthode des secantes et la méthode par dichotomie```

# %%
#1)Calcul approximative de f(x) = 0 
import math
def f(x):
    return x**3 - 2*x**2 + 2
def g(x):
    return 3*x**2 - 4*x
def méthode_newton(x_n,e):
    n = 0
    dif = 2*e
    while dif > e :
        y = x_n-f(x_n)/g(x_n)
        n = n+1
        return y,n
méthode_newton(1,0.001)
# Out:
# (2.0, 1)

# %%
#2)Tracer la courbre en python
import numpy as np
import matplotlib.pyplot as plt
   
def g(f,x,x0):
    tangent = g * (x - x0) + f(x0)
    return tangent
    
    
def f(x):
    return x**3 - 2*x**2 + 2

def g(x):
    return 3*x**2 - 4*x

racines = np.random.uniform(-1, 3,30)

for a in racines:
    tangente_x = np.linspace(a-0.2, a+0.2)
    tangente_y = g(a) * (tangente_x - a) + f(a)
    plt.plot(tangente_x, tangente_y)


plt.axvline(0, color='red',linewidth=1.5)
#plt.axvline(1, color='red',linewidth=1.5)
#plt.axvline(2, color='red',linewidth=1.5)
#plt.axvline(3, color='red',linewidth=1.5)
plt.axhline(0, color='black', linewidth=1.5)
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title("Méthode Newton en python")
plt.grid(True)
plt.show()

# %% [markdown]
# ### Calcul d'intégrale

# %%
#3)Calcule: ∫|f-g|=φ(h)
from scipy.integrate import quad
import numpy as np
import random

def f(x):
    return x**3 - 2*x**2 + 2

def g(x):
    return 3*x**2 - 4*x

def integrale(x):
    return abs(f(x) - g(x))

H = np.random.uniform(0, 3)

resultat_intégrale, erreur = quad(integrale, 0, H)

print("Pour h = ",H)
print("l'intégrale est ",resultat_intégrale)
# Out:
# Pour h =  2.4184647272594058
# l'intégrale est  4.7733143627570245

# %%
import math
def f (x) :
    return x**3 - 2*x**2 + 2
def methode_trapèze(a,b,n) :
    p= (b-a)/n
    s=0
    for i in range(n):
        s = s + (b-a)*(f(i)+f(i+p))*p/2
        a = a + p
    return [s]

methode_trapèze(0,1,3)
# Out:
# [1.1604938271604937]

# %%
#4)Calculer la somme des intégrales de cette courbe
import math
def f (x) :
    return x**3 - 2*x**2 + 2
def methode_trapèze(a,b,n) :
    p = (b-a)/n
    s = 0
    for i in range(n):
        s = (b-a)*(f(i)+f(i+p))*p/2
        a = a + p
    return [s]

methode_trapèze(0,1,3)
# Out:
# [0.32304526748971196]

# %%
def f (x):
    return x**3 - 2*x**2 + 2
def méthode_rectangle(a,b,n) :
    p=(b-a) /n
    s=0
    for i in range(n):
        s=s+p*f(a)
        a+=p
    return s
méthode_rectangle(0,1,10)
# Out:
# 1.6325

# %% [markdown]
# ### Méthode par Dichotomie

# %% [markdown]
# ```
# Fonction dichotomie(valeur de depart 'a', valeur de fin 'b' , tolérance 'e')
# Tant que (b - a) > e
#     m ← (a + b) / 2
#     Si (f(a)*f(m) ≤ 0) alors
#        b ← m
#     sinon
#        a ← m
#     Fin Si
# Fin Tant que
# ```

# %%
def f(x):
    return x**3 - 2*x**2 + 2
def dichotomie(a, b, e):
    while (b - a) > e:
        m = (a + b) / 2
        if f(a) * f(m) <= 0:
            b = m
        else:
            a = m
    return (a + b) / 2

dichotomie(-2,2,0.001)
# Out:
# -0.83935546875

# %% [markdown]
# ### Méthode des sécantes

# %%
def f(x):
    return x**3 -2*x**2 + 2
def secante(a,b,e):
    while True:
        x = b - (b - a) * f(b) / (f(b) - f(a))
        if abs(x - b) <= 10**(-e):
            return x
        else:
            a, b = b, x
secante(-2,2,0.001)
# Out:
# 1.5

# %% [markdown]
# ### Les fonctions utilisées dans les programmes

# %%
def f(x):
    return x**3 - 2*x**2 + 2

def g(x):
    return 3*x**2 - 4*x

# %%
import matplotlib.pyplot as plt
import numpy as np

# Fonction hauteur du ballon
def y(t):
    return -5 * t**2 + 20 * t + 1

# Temps
t = np.linspace(0, 5, 100)  # On choisit une plage de temps de 0 à 5 secondes

# Hauteur correspondante
height = y(t)

# Tracé du graphique
plt.figure(figsize=(10, 6))
plt.plot(t, height, label='Hauteur du ballon $y(t) = -5t^2 + 20t + 1$')

# Ligne horizontale pour le sol (y=0)
plt.axhline(y=0, color='r', linestyle='--', label='Sol')

# Marquer le point où la hauteur est nulle (t0 = 4.0333)
t_sol = 4.0333
plt.plot(t_sol, 0, 'ro')  # Point rouge à l'intersection avec le sol
plt.text(t_sol + 0.1, 0.1, f'Touché le sol à t = {t_sol:.2f} s', fontsize=12)

# Personnalisation du graphique
plt.title('Évolution de la hauteur du ballon dans le temps')
plt.xlabel('Temps (s)')
plt.ylabel('Hauteur (m)')
plt.legend()
plt.grid(True)
plt.ylim(-10, 25)  # Limite verticale pour mieux voir le trajet du ballon
plt.xlim(0, 5)     # Limite horizontale jusqu'à 5 secondes

# Afficher le graphique
plt.show()
